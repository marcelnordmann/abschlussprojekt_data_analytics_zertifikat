# %% [markdown]
# # Daten Aufbereitung

# %% [markdown]
# ## Daten importieren

# %% [markdown]
# ### Bibliotheken importieren

# %%
# Datenverarbeitung
import pandas as pd

# Displaybreite anpassen
from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ### Daten einlesen

# %%
# feather Datei als df einlesen
df = pd.read_feather('data_kiva.feather')

# df ausgeben
df
# Out:
#         funded_amount  loan_amount             activity          sector  \
# 0               300.0        300.0  Fruits & Vegetables            Food
# 1               575.0        575.0             Rickshaw  Transportation
# 2               150.0        150.0       Transportation  Transportation
# 3               200.0        200.0           Embroidery            Arts
# 4               400.0        400.0           Milk Sales            Food
# ...               ...          ...                  ...             ...
# 671200            0.0         25.0            Livestock     Agriculture
# 671201           25.0         25.0            Livestock     Agriculture
# 671202            0.0         25.0                Games   Entertainment
# 671203            0.0         25.0            Livestock     Agriculture
# 671204            0.0         25.0            Livestock     Agriculture
#
#                                                       use country_code  \
# 0                 To buy seasonal, fresh fruits to sell.            PK
# 1       to repair and maintain the auto rickshaw used ...           PK
# 2       To repair their old cycle-van and buy another ...           IN
# 3       to purchase an embroidery machine and a variet...           PK
# 4                                to purchase one buffalo.           PK
# ...                                                   ...          ...
# 671200  [True, u'para compara: cemento, arenya y ladri...           PY
# 671201  [True, u'to start a turducken farm.'] - this l...           KE
# 671202                                               None           KE
# 671203  [True, u'to start a turducken farm.'] - this l...           KE
# 671204  [True, u'to start a turducken farm.'] - this l...           KE
#
#          country        region currency  term_in_months  lender_count  \
# 0       Pakistan        Lahore      PKR            12.0            12
# 1       Pakistan        Lahore      PKR            11.0            14
# 2          India     Maynaguri      INR            43.0             6
# 3       Pakistan        Lahore      PKR            11.0             8
# 4       Pakistan  Abdul Hakeem      PKR            14.0            16
# ...          ...           ...      ...             ...           ...
# 671200  Paraguay    Concepción      USD            13.0             0
# 671201     Kenya          None      KES            13.0             1
# 671202     Kenya          None      KES            13.0             0
# 671203     Kenya          None      KES            13.0             0
# 671204     Kenya          None      KES            13.0             0
#
#        borrower_genders repayment_interval
# 0                female          irregular
# 1        female, female          irregular
# 2                female             bullet
# 3                female          irregular
# 4                female            monthly
# ...                 ...                ...
# 671200           female            monthly
# 671201           female            monthly
# 671202             None            monthly
# 671203           female            monthly
# 671204           female            monthly
#
# [671205 rows x 13 columns]

# %% [markdown]
# ## DF kennenlernen

# %%
# allgemeine Infos über Spalten einholen
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 671205 entries, 0 to 671204
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   funded_amount       671205 non-null  float64
#  1   loan_amount         671205 non-null  float64
#  2   activity            671205 non-null  object
#  3   sector              671205 non-null  object
#  4   use                 666972 non-null  object
#  5   country_code        671197 non-null  object
#  6   country             671205 non-null  object
#  7   region              614405 non-null  object
#  8   currency            671205 non-null  object
#  9   term_in_months      671205 non-null  float64
#  10  lender_count        671205 non-null  int64
#  11  borrower_genders    666984 non-null  object
#  12  repayment_interval  671205 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 71.7+ MB

# %% [markdown]
# **Erkenntnis:**
# - 'use', 'country_code', 'region' & 'borrower_genders' enthält NULL-Werte -> **Fehlende Werte**
# - dtype scheint zu passen (bis auf manche floats, die ggf. ints sein könnten/müssten)

# %%
# Spalten mit NULL-Werte nochmals identifizieren
df.isnull().sum().sort_values(ascending=False)
# Out:
# region                56800
# use                    4233
# borrower_genders       4221
# country_code              8
# funded_amount             0
# loan_amount               0
# activity                  0
# sector                    0
# country                   0
# currency                  0
# term_in_months            0
# lender_count              0
# repayment_interval        0
# dtype: int64

# %% [markdown]
# **Erkenntnis:**
# - **fehlende Werte** in 'use', 'country_code', 'region' & 'borrower_genders'

# %%
# allgemeine Infos über statistische Werte in numerischen Spalten einholen
df.describe()
# Out:
#        funded_amount    loan_amount  term_in_months   lender_count
# count  671205.000000  671205.000000   671205.000000  671205.000000
# mean      785.995061     842.397107       13.739022      20.590922
# std      1130.398941    1198.660073        8.598919      28.459551
# min         0.000000      25.000000        1.000000       0.000000
# 25%       250.000000     275.000000        8.000000       7.000000
# 50%       450.000000     500.000000       13.000000      13.000000
# 75%       900.000000    1000.000000       14.000000      24.000000
# max    100000.000000  100000.000000      158.000000    2986.000000

# %% [markdown]
# **Erkenntnis:**
# - alle max Werte sehr hoch -> **Extremwerte?**

# %%
# Infos über unique values der Spalten einholen
df.nunique()
# Out:
# funded_amount            610
# loan_amount              479
# activity                 163
# sector                    15
# use                   423452
# country_code              86
# country                   87
# region                 12695
# currency                  67
# term_in_months           148
# lender_count             503
# borrower_genders       11298
# repayment_interval         4
# dtype: int64

# %% [markdown]
# **Erkenntnis:**
# - Daten enthalten sehr viele unique values in den Spalten (es scheint wenig Einschränkungen gegeben zu haben bei Anmeldung)

# %% [markdown]
# ## Duplikate

# %% [markdown]
# ### Identifizierung

# %%
# Zeilen ausgeben, die IN JEDER SPALTE ein Duplikat sind
df.loc[df.duplicated(keep=False), :]
# Out:
#         funded_amount  loan_amount     activity         sector  \
# 327             275.0        275.0      Farming    Agriculture
# 392             100.0        100.0  Home Energy   Personal Use
# 405             100.0        100.0  Home Energy   Personal Use
# 498             100.0        100.0  Home Energy   Personal Use
# 606             100.0        100.0  Home Energy   Personal Use
# ...               ...          ...          ...            ...
# 671200            0.0         25.0    Livestock    Agriculture
# 671201           25.0         25.0    Livestock    Agriculture
# 671202            0.0         25.0        Games  Entertainment
# 671203            0.0         25.0    Livestock    Agriculture
# 671204            0.0         25.0    Livestock    Agriculture
#
#                                                       use country_code  \
# 327           to buy fertilizers and other farm supplies.           PH
# 392                                  to buy a solar lamp.           SV
# 405                          to buy a solar-powered lamp.           SV
# 498                          to buy a solar-powered lamp.           SV
# 606                          to buy a solar-powered lamp.           SV
# ...                                                   ...          ...
# 671200  [True, u'para compara: cemento, arenya y ladri...           PY
# 671201  [True, u'to start a turducken farm.'] - this l...           KE
# 671202                                               None           KE
# 671203  [True, u'to start a turducken farm.'] - this l...           KE
# 671204  [True, u'to start a turducken farm.'] - this l...           KE
#
#             country                  region currency  term_in_months  \
# 327     Philippines  Brookes Point, Palawan      PHP             8.0
# 392     El Salvador                    None      USD            14.0
# 405     El Salvador                    None      USD            14.0
# 498     El Salvador                    None      USD            14.0
# 606     El Salvador                    None      USD            14.0
# ...             ...                     ...      ...             ...
# 671200     Paraguay              Concepción      USD            13.0
# 671201        Kenya                    None      KES            13.0
# 671202        Kenya                    None      KES            13.0
# 671203        Kenya                    None      KES            13.0
# 671204        Kenya                    None      KES            13.0
#
#         lender_count borrower_genders repayment_interval
# 327                8           female          irregular
# 392                4             male            monthly
# 405                4             male            monthly
# 498                4             male            monthly
# 606                4             male            monthly
# ...              ...              ...                ...
# 671200             0           female            monthly
# 671201             1           female            monthly
# 671202             0             None            monthly
# 671203             0           female            monthly
# 671204             0           female            monthly
#
# [34930 rows x 13 columns]

# %% [markdown]
# ### Umgang

# %% [markdown]
# Diese knapp 35k Zeilen sind geprüft auf alle Spalten mindestens 2 mal im Datensatz vorhanden. Das lässt vermuten, dass keine Systemfehler oder falsche Eingaben ein paar Duplikate produziert haben.<br>
# Der Datensatz enthält die Historie abgeschlossener Projekte des letzten Jahres - allerdings OHNE Zeitstempel!<br>
# Vermutung: Manche Personen melden das exakt gleiche Projekt mehrfach hintereinander an. Vielleicht haben sie kein Geld oder zu wenig bekommen und wollten es nochmal probieren. Oder sie hatten Erfolg und benötigen noch mehr Geld.<br>
# Ohne einen genauer Zeitstempel kann keine exakte Aussage über die Duplikate getroffen werden. Außerdem würde ein Löschen viele interessante Daten für die spätere Analyse entferne (bspw. haben vielleicht Personen aus Kenia ganz viele Projekte angefragt, aber kein Geld bekommen)<br>
# **Daher lasse ich alle Zeilen drin.**<br>
# Ggf. kann man diese mehrfach angefragten Projekte sogar analysieren?!

# %% [markdown]
# ## Fehlende Werte

# %% [markdown]
# ### Synonyme

# %% [markdown]
# #### Synonyme in Text-Spalten

# %% [markdown]
# Oben wurde bereits herausgearbeitet, dass viele Spalten sehr viele unique values haben. Deshalb schaue ich hier bei den Spalten mit "wenigen" unique values nach, ob ich Synonyme für fehlende Werte finden kann.<br>

# %%
# 'sector' prüfen
df.sector.unique()
# Out:
# array(['Food', 'Transportation', 'Arts', 'Services', 'Agriculture',
#        'Manufacturing', 'Wholesale', 'Retail', 'Clothing', 'Construction',
#        'Health', 'Education', 'Personal Use', 'Housing', 'Entertainment'],
#       dtype=object)

# %%
# 'country' prüfen
df.country.unique()
# Out:
# array(['Pakistan', 'India', 'Kenya', 'Nicaragua', 'El Salvador',
#        'Tanzania', 'Philippines', 'Peru', 'Senegal', 'Cambodia',
#        'Liberia', 'Vietnam', 'Iraq', 'Honduras', 'Palestine', 'Mongolia',
#        'United States', 'Mali', 'Colombia', 'Tajikistan', 'Guatemala',
#        'Ecuador', 'Bolivia', 'Yemen', 'Ghana', 'Sierra Leone', 'Haiti',
#        'Chile', 'Jordan', 'Uganda', 'Burundi', 'Burkina Faso',
#        'Timor-Leste', 'Indonesia', 'Georgia', 'Ukraine', 'Kosovo',
#        'Albania', 'The Democratic Republic of the Congo', 'Costa Rica',
#        'Somalia', 'Zimbabwe', 'Cameroon', 'Turkey', 'Azerbaijan',
#        'Dominican Republic', 'Brazil', 'Mexico', 'Kyrgyzstan', 'Armenia',
#        'Paraguay', 'Lebanon', 'Samoa', 'Israel', 'Rwanda', 'Zambia',
#        'Nepal', 'Congo', 'Mozambique', 'South Africa', 'Togo', 'Benin',
#        'Belize', 'Suriname', 'Thailand', 'Nigeria', 'Mauritania',
#        'Vanuatu', 'Panama', 'Virgin Islands',
#        'Saint Vincent and the Grenadines',
#        "Lao People's Democratic Republic", 'Malawi', 'Myanmar (Burma)',
#        'Moldova', 'South Sudan', 'Solomon Islands', 'China', 'Egypt',
#        'Guam', 'Afghanistan', 'Madagascar', 'Namibia', 'Puerto Rico',
#        'Lesotho', "Cote D'Ivoire", 'Bhutan'], dtype=object)

# %%
# 'country_code' prüfen
df.country_code.unique()
# Out:
# array(['PK', 'IN', 'KE', 'NI', 'SV', 'TZ', 'PH', 'PE', 'SN', 'KH', 'LR',
#        'VN', 'IQ', 'HN', 'PS', 'MN', 'US', 'ML', 'CO', 'TJ', 'GT', 'EC',
#        'BO', 'YE', 'GH', 'SL', 'HT', 'CL', 'JO', 'UG', 'BI', 'BF', 'TL',
#        'ID', 'GE', 'UA', 'XK', 'AL', 'CD', 'CR', 'SO', 'ZW', 'CM', 'TR',
#        'AZ', 'DO', 'BR', 'MX', 'KG', 'AM', 'PY', 'LB', 'WS', 'IL', 'RW',
#        'ZM', 'NP', 'CG', 'MZ', 'ZA', 'TG', 'BJ', 'BZ', 'SR', 'TH', 'NG',
#        'MR', 'VU', 'PA', 'VI', 'VC', 'LA', 'MW', 'MM', 'MD', 'SS', 'SB',
#        'CN', 'EG', 'GU', 'AF', 'MG', None, 'PR', 'LS', 'CI', 'BT'],
#       dtype=object)

# %%
# 'currency' prüfen
df.currency.unique()
# Out:
# array(['PKR', 'INR', 'KES', 'NIO', 'USD', 'TZS', 'PHP', 'PEN', 'XOF',
#        'LRD', 'VND', 'HNL', 'MNT', 'COP', 'GTQ', 'TJS', 'BOB', 'YER',
#        'KHR', 'GHS', 'SLL', 'HTG', 'CLP', 'JOD', 'UGX', 'BIF', 'IDR',
#        'GEL', 'UAH', 'EUR', 'ALL', 'CRC', 'XAF', 'TRY', 'AZN', 'DOP',
#        'BRL', 'MXN', 'KGS', 'AMD', 'PYG', 'LBP', 'WST', 'ILS', 'RWF',
#        'ZMW', 'NPR', 'MZN', 'ZAR', 'BZD', 'SRD', 'NGN', 'VUV', 'XCD',
#        'MWK', 'LAK', 'MMK', 'ZWD', 'MDL', 'SSP', 'SBD', 'CNY', 'EGP',
#        'MGA', 'NAD', 'LSL', 'THB'], dtype=object)

# %%
# 'repayment_interval' prüfen
df.repayment_interval.unique()
# Out:
# array(['irregular', 'bullet', 'monthly', 'weekly'], dtype=object)

# %% [markdown]
# **Erkenntnis:**
# - in Spalten mit "wenigen" unique values habe ich keine Synonyme für fehlende Werte gefunden
# - falls fehlende Werte in den anderen Spalten, die ich nicht geprüft habe, drin sind, fallen diese mir später in der Analyse auf

# %% [markdown]
# #### Synonyme in numerischen Spalten

# %% [markdown]
# Zunächst nochmal die statistischen Werte anschauen:

# %%
# allgemeine Infos über statistische Werte in numerischen Spalten einholen
df.describe()
# Out:
#        funded_amount    loan_amount  term_in_months   lender_count
# count  671205.000000  671205.000000   671205.000000  671205.000000
# mean      785.995061     842.397107       13.739022      20.590922
# std      1130.398941    1198.660073        8.598919      28.459551
# min         0.000000      25.000000        1.000000       0.000000
# 25%       250.000000     275.000000        8.000000       7.000000
# 50%       450.000000     500.000000       13.000000      13.000000
# 75%       900.000000    1000.000000       14.000000      24.000000
# max    100000.000000  100000.000000      158.000000    2986.000000

# %% [markdown]
# Es fallen keine extrem niedrigen oder hohen Werte direkt auf. Dennoch prüfe ich zwei der Max-Werte:

# %%
# Zeilen mit term in months über 150
df.loc[df.loc[:, 'lender_count']>1600, :]
# Out:
#         funded_amount  loan_amount                   activity       sector  \
# 70499        100000.0     100000.0                Agriculture  Agriculture
# 197210        49950.0      49950.0  Renewable Energy Products       Retail
# 408295        50000.0      50000.0                   Clothing     Clothing
# 496715        50000.0      50000.0                Agriculture  Agriculture
# 509048        50000.0      50000.0                    Poultry  Agriculture
# 544548        50000.0      50000.0                     Health       Health
# 565733        50000.0      50000.0                Agriculture  Agriculture
# 583307        50000.0      50000.0                Agriculture  Agriculture
# 614922        50000.0      50000.0         Water Distribution     Services
# 631904        50000.0      50000.0                Agriculture  Agriculture
#
#                                                       use country_code  \
# 70499   create more than 300 jobs for women and farmer...           HT
# 197210  to import and stock clean energy products such...           HT
# 408295  to set up a garment social business that will ...           AL
# 496715  to fund the harvest of seeds of 6,000 smallhol...           MG
# 509048  to purchase chicken feed & a delivery vehicle ...           TZ
# 544548  to provide community trauma services in South ...           SS
# 565733  to pay 600 farming families 100% above market ...           EC
# 583307  to support 800+ farmers by improving their pro...           GT
# 614922  to set up 13 new clean water businesses in nor...           GH
# 631904  double cashew nut export output and hire about...           CI
#
#               country          region currency  term_in_months  lender_count  \
# 70499           Haiti       Les Cayes      USD            75.0          2986
# 197210          Haiti  Port-au-Prince      USD            26.0          1605
# 408295        Albania          Cerrik      USD            97.0          1626
# 496715     Madagascar        Tsihombe      USD            22.0          1606
# 509048       Tanzania   Dar es Salaam      USD            14.0          1765
# 544548    South Sudan            Juba      USD             8.0          1609
# 565733        Ecuador           Quito      USD            14.0          1689
# 583307      Guatemala  Quetzaltenango      USD            20.0          1671
# 614922          Ghana          Tamale      USD            14.0          1688
# 631904  Cote D'Ivoire           Kolia      USD            10.0          1706
#
#        borrower_genders repayment_interval
# 70499            female          irregular
# 197210           female            monthly
# 408295             male            monthly
# 496715             male          irregular
# 509048           female          irregular
# 544548           female             bullet
# 565733           female          irregular
# 583307             male            monthly
# 614922           female          irregular
# 631904           female          irregular

# %%
# Zeilen mit term in months über 150
df.loc[df.loc[:, 'term_in_months']>150, :]
# Out:
#         funded_amount  loan_amount                activity     sector  \
# 215863         6725.0       6725.0  Higher education costs  Education
# 280535         6675.0       6675.0  Higher education costs  Education
# 281445         8900.0       8900.0  Higher education costs  Education
#
#                                                       use country_code  \
# 215863  To cover educational expenses for pursuing a M...           DO
# 280535             to pay for higher education expenses.            DO
# 281445                    to pay further education costs.           DO
#
#                    country                    region currency  term_in_months  \
# 215863  Dominican Republic  San Francisco de Macoris      DOP           158.0
# 280535  Dominican Republic             Santo Domingo      DOP           154.0
# 281445  Dominican Republic             Santo Domingo      DOP           156.0
#
#         lender_count borrower_genders repayment_interval
# 215863           244           female          irregular
# 280535           207             male          irregular
# 281445           253           female          irregular

# %% [markdown]
# **Erkenntnis:**
# - es scheint alles seine Richtigkeit zu haben mit den Max-Werten

# %% [markdown]
# ### NULL-Werte

# %% [markdown]
# Zunächst noch einmal die Spalten mit NULL-Werten identifizieren:

# %%
# Spalten mit NULL-Werte nochmals identifizieren
df.isnull().sum().sort_values(ascending=False)
# Out:
# region                56800
# use                    4233
# borrower_genders       4221
# country_code              8
# funded_amount             0
# loan_amount               0
# activity                  0
# sector                    0
# country                   0
# currency                  0
# term_in_months            0
# lender_count              0
# repayment_interval        0
# dtype: int64

# %% [markdown]
# #### Spalte 'region'

# %%
# NULL-Werte in Spalte 'region' genauer anschauen
df.loc[df.loc[:, 'region'].isnull(), :]
# Out:
#         funded_amount  loan_amount       activity         sector  \
# 5               250.0        250.0       Services       Services
# 49              450.0        450.0  General Store         Retail
# 54              225.0        225.0    Food Market           Food
# 67              125.0        125.0         Energy       Services
# 70             2000.0       2000.0         Retail         Retail
# ...               ...          ...            ...            ...
# 671197            0.0         25.0      Livestock    Agriculture
# 671201           25.0         25.0      Livestock    Agriculture
# 671202            0.0         25.0          Games  Entertainment
# 671203            0.0         25.0      Livestock    Agriculture
# 671204            0.0         25.0      Livestock    Agriculture
#
#                                                       use country_code  \
# 5       purchase leather for my business using ksh 20000.           KE
# 49                                    to stock his store.           SV
# 54      to purchase various seasonal items to resell: ...           SN
# 67                    purchase solar lanterns for resale.           KE
# 70      to install a display window and a sunshade for...           IQ
# ...                                                   ...          ...
# 671197  Pretend the issue with loan got addressed by K...           KE
# 671201  [True, u'to start a turducken farm.'] - this l...           KE
# 671202                                               None           KE
# 671203  [True, u'to start a turducken farm.'] - this l...           KE
# 671204  [True, u'to start a turducken farm.'] - this l...           KE
#
#             country region currency  term_in_months  lender_count  \
# 5             Kenya   None      KES             4.0             6
# 49      El Salvador   None      USD            14.0            18
# 54          Senegal   None      XOF            14.0             7
# 67            Kenya   None      KES             3.0             6
# 70             Iraq   None      USD            15.0            71
# ...             ...    ...      ...             ...           ...
# 671197        Kenya   None      KES            13.0             0
# 671201        Kenya   None      KES            13.0             1
# 671202        Kenya   None      KES            13.0             0
# 671203        Kenya   None      KES            13.0             0
# 671204        Kenya   None      KES            13.0             0
#
#        borrower_genders repayment_interval
# 5                female          irregular
# 49                 male            monthly
# 54               female            monthly
# 67                 male          irregular
# 70                 male            monthly
# ...                 ...                ...
# 671197           female            monthly
# 671201           female            monthly
# 671202             None            monthly
# 671203           female            monthly
# 671204           female            monthly
#
# [56800 rows x 13 columns]

# %% [markdown]
# **Erkenntnis:**
# - sehr viele Zeilen sind von NULL-Werten in 'region' betroffen
# - Frage: welche Länder stecken dahinter?

# %%
# unique Länder, die hinter NaN in 'region' Zeilen stecken
df.loc[df.loc[:, 'region'].isnull(), 'country'].unique()
# Out:
# array(['Kenya', 'El Salvador', 'Senegal', 'Iraq', 'United States', 'Peru',
#        'Tanzania', 'Guatemala', 'Colombia', 'Indonesia', 'Kosovo',
#        'Timor-Leste', 'Turkey', 'Philippines', 'Palestine', 'Burundi',
#        'Tajikistan', 'Honduras', 'Jordan', 'Mexico', 'Lebanon', 'Albania',
#        'Nicaragua', 'Bolivia', 'Israel', 'Rwanda', 'Azerbaijan',
#        'Ecuador', 'Mongolia', 'Haiti', 'Cambodia', 'Sierra Leone',
#        'Yemen', 'Zimbabwe', 'Paraguay', 'Uganda', 'Armenia',
#        'Dominican Republic', 'Benin', 'Belize', 'Ghana', 'Mozambique',
#        'Zambia', 'Samoa', 'Brazil', 'Panama', 'Pakistan', 'Burkina Faso',
#        'Suriname', 'Virgin Islands', 'Togo', 'South Africa', 'Malawi',
#        'Nigeria', 'Liberia', 'Vietnam', 'Costa Rica', 'Guam',
#        'Myanmar (Burma)', 'Mali', 'Madagascar',
#        'The Democratic Republic of the Congo', 'Cameroon', 'Georgia',
#        'Puerto Rico', 'South Sudan', 'Moldova', 'Chile', 'Kyrgyzstan',
#        'India', 'China', 'Bhutan'], dtype=object)

# %% [markdown]
# **Erkenntnis:**
# - viele verschiedene Länder stecken hinter diesen Zeilen
# - Frage: kann man NULL-Werte in 'region' sinnvoll auffüllen? Steckt vielleicht oft nur eine Region pro Land dahinter? Stichprobenartige Prüfung:

# %%
# unique Regionen, die bei Kenya hinterlegt sind
df.loc[df.loc[:, 'country']=='Kenya', 'region'].unique()
# Out:
# array([None, 'Voi', 'Likoni', 'Nanyuki', 'Samburu', 'Nairobi West',
#        'Tiribe', 'malindi', 'Kiambu', 'Kericho', 'Mariakani', 'Nakuru',
#        'Ngara', 'Kaloleni', 'Nyahururu', 'Ndunyu Njeru', 'Narok',
#        'Naivasha', 'Olkalou', 'Embu-town', 'Kangemi,Nairobi', 'Thika',
#        'Kisauni', 'Ndaragwa', 'Nyamira', 'Kisii', 'Tala;Kangundo',
#        'Thika Road', 'Kitale', 'Kitengela;Nairobi', 'Mwandoni, Mombasa',
#        'Sakutiek-Naivasha', 'Litein', 'Maua', 'Kitengela', 'Eldoret',
#        'Mwingi', 'Msambweni', 'Njabini', "Murang'a", 'Nyandarua South',
#        'Limuru', 'Ongata-Rongai', 'Nyandarua', 'Kilifi', 'nyeri', 'Ngong',
#        'Nairobi', 'Sindo', 'Kangemi, Nairobi', 'Kuria west', 'Kakamega',
#        'Nairobi Central', 'Mombasa', 'Mukuru (Nairobi)', 'karatina',
#        'ELDAMA RAVINE', 'Matuu', 'Katito', 'Kisumu', 'Changamwe',
#        'Kisauni ;Mombasa', 'Bamburi, Mombasa', 'KABARNET', 'Juja',
#        'Usenge;Kisumu', 'Mwambalazi', 'Mpeketoni, Lamu', 'Webuye',
#        'KAMELIL, NANDI', 'Lucky Rhino', 'Ogongo', 'Ogonga', 'Kapsabet',
#        'Kinungi', 'Kisima Cha Neema', 'Muranga', 'Matete', 'Busia',
#        'Chwele', 'Kakamega North', 'Matete-', 'kakamega south', 'Chuka',
#        'Mwembe Tayari, Mombasa', 'Elimu na Maarifa', 'Mangwei', 'Gumbato',
#        'Magodi', 'Lunga Lunga', 'Mkongani', 'Malava', 'Mwapala',
#        'Eastland', 'KAPYAGAN CHEMUNDU, KAPSABET', 'Vihiga', 'Kongowea',
#        'Tijara', 'Ukunda Town', 'Kangundo', 'Mwea', 'Ngalaiya;Tala',
#        'Keroka', 'Kibwezi', 'Emali', 'kaimosi kakaemga', 'KAMALIL, NANDI',
#        'Kibuye, Kisumu', 'AWASI', 'Makueni', 'MUTWOT, KAPSABET', 'Tala',
#        'Central Maragoli Kakamega', 'Nkubu', 'Bomet ;Narok', 'Muhuru',
#        'Oloitoktok', 'Mwiki', 'Kerugoya', 'Wote , Makueni',
#        'Shienwe kakamega', 'Shirere Kakamega', 'Siongiroi', 'MARIGAT',
#        'Nandi Hills', 'Migori', 'Shikoyi Kakamega',
#        'village market,nairobi', 'Machakos', 'Majengo Kakamega',
#        'Kabaa-Matuu', 'Mumias', 'Siaya', 'Molo', 'Ololailumtia',
#        'KAPLONG', 'mamboleo Kisumu', 'Meru', 'Lugari', 'Ilesi kakamega',
#        'Mkwajuni', 'Majengo', 'Kongowea, Mombasa', 'Makunga Kakamega',
#        'Miritini, Mombasa', 'Majaoni, Mombasa', 'Shieywe Vihiga',
#        'Tudor, Mombasa', 'Barsheba, Mombasa', 'Vikwatani, Mombasa',
#        'Dandora Nairobi', 'Murhanda-Kakamega', 'Kimana, Oloitoktok',
#        'Taveta', 'Bungoma', 'Ingotse Kakamega', 'Shinyalu-kakamega',
#        'Oasis', 'Shikoti-kakamega', 'North Butsotso-kakamega', 'Ojawa',
#        'Kiambariki; Nyandarua', 'Kipasi', 'Mirogi', 'Kilibwoni, Kapsabet',
#        'Kamato', 'Mazeras; Mariakani', 'Eastleigh, Nairobi',
#        'shichirai-kakamega', 'Chepkumia Kakamega', 'Kaptumo, Kapsabet',
#        'Kojungo Junction-mamboleo', 'Nkoilale', 'Nyalenda;Kisumu',
#        'Bondeni estate-kakamega', 'Kamukuywa', 'Koyango Manyatta-kisumu',
#        'MOGOTIO', 'Bissil;Kajiado', 'Koibatek', 'Olekaitioriori',
#        'Sultan-hamud-Emali', 'Kapsowar', 'Magunga', 'Manyatta Kisumu',
#        'Bomet', 'Bondo', 'Chepsonoi', 'Thika-Town', 'Usenge Town',
#        'Luanda', 'Isinet', 'Dagoretti', 'Nguluni;Tala', 'Kinoo, Nairobi',
#        'Rongo', 'Maili Saba;Kitale', 'Malaa', 'Misyani-Tala', 'Kangemi',
#        'Kayole  Nairobi', 'Uthiru', 'Githurai, Nairobi', 'Naikarra',
#        'Riruta', 'Bakarani, Mombasa', 'Kagujo', 'Kenyenya',
#        'Uthiru,Nairobi', 'Embu', 'Gatitu', 'Githunguri',
#        'Kabimoi, Eldama Ravine', 'Mombassa', 'Butere', 'Kuria East',
#        'NDHIWA', 'Dida', 'Bungoma South', 'Ikinu', 'Teso',
#        'Kilifi Township', 'Sokoke', 'Ganze', 'Ngerenya', 'Nambale',
#        'Tezo', 'Githiga', 'Kauma', 'Vitengeni', 'Mwahera', 'Mmbale',
#        'Lango Baya', 'Mtsara wa Tsatsu', 'Ndigiria', 'Mrima wa Ndege',
#        'Takaungu', 'Vyambani', 'Ziani', 'Chasimba', 'Jaribuni', 'Mavueni',
#        'Mwanamwinga', 'Juhudi', 'Palakumi', 'Mariani', 'Kinarani',
#        'Eastlands', 'Giathaini', 'Homa Bay', 'Kawangware', 'Iriani',
#        'Homabay', 'Buxton Mombasa', 'Nakuru West', 'Nakuru East',
#        'Changamwe, Mombasa', 'Kilfi', 'Kabartonjo, Baringo county',
#        'Barwesa Baringo County', 'Laikipia', 'Kamkunji, Nairobi.',
#        'Muthurwa, Nairobi', 'Saika,Nairobi',
#        'Kwa Njenga, Mukuru, Nairobi.', 'Babadogo;Nairobi',
#        'Mogadishu, Somalia', 'Engineer', 'Maweni;Malindi',
#        'Kwa Reuben, Nairobi.', 'Kitiri;Nyandarua South',
#        'Mtito Andei , kibwezi', 'Bamba Kilifi', 'Makadara, Nairobi.',
#        'Kiambiu Makadara, Nairobi.', 'Yala', 'Kamulu', 'Maweni;Mombasa',
#        'Kirinyaga', 'Kiserian;Nairobi', 'Mathare, Nairobi.', 'Mikinduri',
#        'Githurai', 'Masavoni', 'Viwandani', 'Lamu', 'Kayaba, Nairobi',
#        'Kalile ;Tala', 'Chaani, Mombasa', 'Lelan', 'Kamkunji, Majengo.',
#        'Isiolo', 'Mkilo Men', 'Mikindani, Mombasa',
#        'Mishomuhoroni Mombasa', 'Jomvu, Mombasa', 'Tena-Nairobi',
#        'Awendo', 'Kiwa Island', 'Viwandani, Nairobi', 'Likoni, Mombasa',
#        'Mtongwe Life A', 'Mtongwe, Mombasa',
#        'Bombolulu-Kisimani, Mombasa', 'Sereolipi', 'Mwamlai Mombasa',
#        'Old town Mombasa', 'Shika Adabu Likoni Mombasa',
#        'Kariobangi South', 'Kiembeni Mombasa', "K'oyango , Kisumu",
#        'Nyeri', 'Homeage', 'Mtopanga; Mombasa', 'Mwamlai, Mombasa',
#        'Ruiru', 'Kikuyu', 'CHEPSIGOT', 'Kishushe', 'Mathare', 'Makadara',
#        'Vikwatani Mombasa', 'Katingani, Emali', 'Lungalunga', 'Boyani',
#        'Balozi, Nairobi', 'Mariakani, Kaloleni', 'Majengo mapya',
#        'Majoreni, Lunga Lunga', 'Ukunda-Mombasa', 'KABISAGA KAPSABET',
#        'Kisauni mombasa', 'Kapture, Kapsabet', 'Bulo Kisimani Mombasa',
#        'West Nairobi', 'East Nairobi', 'Baba Dogo', 'East Nairob',
#        'Jitoni, Mombasa', 'Mwamlai, Chaani Kenya', 'Miknjuni, Miritini',
#        'Mikoroshoni, Mombasa', 'Mabambani', 'Chamunyu, Mombasa',
#        'Concodia, Mombasa', 'Iten', 'Kimilili', 'Muhoroni', 'Kibera',
#        "Moi's Bridge", 'Kombewa', 'Karatina', 'Furunzi;Malindi',
#        'Homebay', 'Mathare North Area 4', 'Huruma, Ngei II',
#        'Thiongo Road, Kangemi', 'Lodwar', 'Nyanza', 'Kapcherop',
#        'Athi river', 'Weema', 'Sirisia', 'Nunguni', 'KYAMBEKE', 'Gatundu',
#        'Lengo', 'Kondele', 'litein', 'AHERO', 'Nandarasi;Nyandarua',
#        'Othaya', 'Luanda;Vihiga', 'Riat,Kisumu', 'Migosi, Kisumu',
#        'Magogoni, Mombasa', 'Obunga;Kisumu', 'Manyatta,Kisumu',
#        'Mwamlai Jomvu, Mombasa', 'Changamka', 'Huruma', 'Kasarani',
#        'Cambodia,Changamwe Mombasa', 'Aldina,Jomvu', 'Aldina,Jomvu Kenya',
#        'Magongo, Mombasa', 'Aldina, Jomvu', 'Majengo Mapya, Mombasa',
#        'Sotik', 'Mwembelegeza,Bamburi Mombasa', 'Marikiti, Mombasa',
#        'Kapsaos, Kapsabet', 'Namalakazi,Aldina Mombasa', 'Vihiga;'],
#       dtype=object)

# %%
# unique Regionen, die bei Lebanon hinterlegt sind
df.loc[df.loc[:, 'country']=='Lebanon', 'region'].unique()
# Out:
# array([None, 'Tyre', 'Saida', 'Qana', 'Jib Jennine', 'Aley', 'Beirut',
#        'Ain Al Helwi', 'Chtoura', 'Tayouneh', 'Nabatieh', 'Baalback',
#        'Ain', 'Dora', 'Dahieh', 'Tripoli', 'Marjeyoun', 'Chouf', 'Spears',
#        'Sidon', 'SME', 'Metn', 'Hay el Selloum', 'Choueifat', 'Baabda',
#        'Khalde', 'Berj Hammoud', 'Ferzol', 'Hermel', 'Bekaa', 'Sarafand',
#        'Jadra', 'Sohmor', 'Halba', 'Tyre 2', 'Koura'], dtype=object)

# %%
# unique Regionen, die bei Ecuador hinterlegt sind
df.loc[df.loc[:, 'country']=='Ecuador', 'region'].unique()
# Out:
# array(['Cuenca', 'Latacunga', 'Charapoto', 'Ventanas', 'Manta',
#        'Jaramijo', 'Tosagua', 'Portoviejo', 'Montecristi', 'Nabón', None,
#        'Puyo', 'Gualaceo', 'Santo Domingo', 'Los Bancos', 'Pujilí',
#        'Paute', '24 de Mayo', 'Jipijapa', 'Chimbo', 'MULALO',
#        'San Miguel', 'Rocafuerte', 'Atuntaqui', 'Pichincha', 'BORBON',
#        'San Lorenzo', 'Azogues', 'San Gabriel', 'Santa Barbara', 'Tulcán',
#        'Guaranda', 'Calceta', 'LIMONES - TELEMBI', 'LAGARTO',
#        'ESMERALDAS', 'RIO VERDE', 'LA TOLA', 'Junin', 'Santa Ana',
#        'Chillanes', 'Montalvo', 'San Clemente', 'Olmedo', 'Carmen',
#        'Pedernales', 'Bahia de Caraquez', 'Puerto Quito', 'Pajan',
#        'Ibarra', 'Otavalo', 'Pusir', 'Ambuqui', 'Lita', 'Mascarilla',
#        'Collapi', 'La Esperanza', 'Quito', 'Cahuasqui', 'Guaniguela',
#        'Tumbabiro', 'Mira', 'Chinambi', 'Carabuela', 'Puerto López',
#        'Azaya', 'Gonzáles Suarez', 'La Carolina', 'Ajumbuela',
#        'Pablo Arenas', 'Sachapamba', 'Colonia', 'Santa Rita', 'Calderon',
#        'San Francisco', 'Alto Tambo', 'Machalilla',
#        'Marianita de Caliche', 'Urcuqui', 'Pugara', 'San Pablo',
#        'Crucita', 'Pijal', 'Imbaya', 'El Carmen', 'Chachimbiro',
#        'El Remolino', 'Cristal', 'San Geronimo', 'Natabuela',
#        'San Antonio', 'Cojimies', 'Chota', 'Buenos Aires', 'Parambas',
#        'Cotacachi', 'Julio Andrade', 'San Javier', 'Limonal', 'Echeandia',
#        'Las Peñas', 'Remolino', 'Luz de America', 'Abdón Calderón',
#        'El Hato', 'Cayambe', 'La Loma', 'Guadual', 'San Jacinto',
#        'Cuambo', 'Valdez', 'Santa Rosa', 'La Florida', 'El Milagro',
#        'Riochico', 'Bolivar', 'Huaca', 'Chiriyacu'], dtype=object)

# %% [markdown]
# **Erkenntnis:**
# - die NULL-Werte in 'region' können nicht sinnvoll aufgefüllt werden, da es eine Text-Spalte ist und kein Muster (wenige Region pro Land) erkennbar ist. Das mit dem meistbenutzten o.Ä. aufzufüllen, wäre einfach geraten. Da Machine Learning nicht das Ziel ist, fällt diese Möglichkeit raus
# - die Zeilen zu löschen würde viele relevante Daten aus anderen Spalten entfernen
# - 'region' zu löschen entfernt zwar komplett die Möglichkeit, die Goegraphie detaillierter als auf Länderebene zu analysieren, allerdings gibt es dort pro Land oft viele Regionen und diese können scheinbar auch frei eingegeben werden. Es sind also ebenfalls sehr schwierig zu analysierende Werte.
#
# **Ergebnis der Erkenntnis:**<br>
# Eine Geoanalyse auf Basis des Landes reicht im ersten Schritt vollkommen aus. Um die Region genauer zu untersuchen, müssten die Daten darüber strukturierte gesammelt werden. Außerdem sollen die Werte aus anderen Zeilen unbedingt beibehalten werden. Darauf können diverse Analysen gemacht werden, die schon jetzt Insights generieren können. **Daher werde ich 'region' löschen.**

# %%
# Entfernen von Spalte 'region'
df.drop(columns='region', inplace=True)

# %% [markdown]
# #### Spalte 'borrower_genders'

# %%
# NULL-Werte in Spalte 'borrower_genders' genauer anschauen
df.loc[df.loc[:, 'borrower_genders'].isnull(), :]
# Out:
#         funded_amount  loan_amount               activity         sector  \
# 140            2975.0       2975.0  Food Production/Sales           Food
# 145            1200.0       1200.0      Personal Expenses   Personal Use
# 170            4250.0       4250.0               Catering           Food
# 412            2350.0       2350.0           Beauty Salon       Services
# 414             725.0        725.0            Agriculture    Agriculture
# ...               ...          ...                    ...            ...
# 671151            0.0         25.0              Livestock    Agriculture
# 671174            0.0         25.0                  Games  Entertainment
# 671178            0.0         25.0              Livestock    Agriculture
# 671185            0.0         25.0              Livestock    Agriculture
# 671202            0.0         25.0                  Games  Entertainment
#
#          use country_code      country currency  term_in_months  lender_count  \
# 140     None           TZ     Tanzania      TZS            10.0           110
# 145     None           PE         Peru      PEN            20.0            44
# 170     None           TZ     Tanzania      TZS            10.0           116
# 412     None           TZ     Tanzania      TZS            10.0            75
# 414     None           SV  El Salvador      USD            20.0            19
# ...      ...          ...          ...      ...             ...           ...
# 671151  None           KE        Kenya      KES            13.0             0
# 671174  None           KE        Kenya      KES            13.0             0
# 671178  None           KE        Kenya      KES            13.0             0
# 671185  None           KE        Kenya      KES            13.0             0
# 671202  None           KE        Kenya      KES            13.0             0
#
#        borrower_genders repayment_interval
# 140                None            monthly
# 145                None            monthly
# 170                None            monthly
# 412                None            monthly
# 414                None            monthly
# ...                 ...                ...
# 671151             None            monthly
# 671174             None            monthly
# 671178             None            monthly
# 671185             None            monthly
# 671202             None            monthly
#
# [4221 rows x 12 columns]

# %% [markdown]
# **Erkenntnis:**
# - folgt nach 'use'

# %% [markdown]
# #### Spalte 'use'

# %%
# NULL-Werte in Spalte 'use' genauer anschauen
df.loc[df.loc[:, 'use'].isnull(), :]
# Out:
#         funded_amount  loan_amount               activity         sector  \
# 140            2975.0       2975.0  Food Production/Sales           Food
# 145            1200.0       1200.0      Personal Expenses   Personal Use
# 170            4250.0       4250.0               Catering           Food
# 412            2350.0       2350.0           Beauty Salon       Services
# 414             725.0        725.0            Agriculture    Agriculture
# ...               ...          ...                    ...            ...
# 671151            0.0         25.0              Livestock    Agriculture
# 671174            0.0         25.0                  Games  Entertainment
# 671178            0.0         25.0              Livestock    Agriculture
# 671185            0.0         25.0              Livestock    Agriculture
# 671202            0.0         25.0                  Games  Entertainment
#
#          use country_code      country currency  term_in_months  lender_count  \
# 140     None           TZ     Tanzania      TZS            10.0           110
# 145     None           PE         Peru      PEN            20.0            44
# 170     None           TZ     Tanzania      TZS            10.0           116
# 412     None           TZ     Tanzania      TZS            10.0            75
# 414     None           SV  El Salvador      USD            20.0            19
# ...      ...          ...          ...      ...             ...           ...
# 671151  None           KE        Kenya      KES            13.0             0
# 671174  None           KE        Kenya      KES            13.0             0
# 671178  None           KE        Kenya      KES            13.0             0
# 671185  None           KE        Kenya      KES            13.0             0
# 671202  None           KE        Kenya      KES            13.0             0
#
#        borrower_genders repayment_interval
# 140                None            monthly
# 145                None            monthly
# 170                None            monthly
# 412                None            monthly
# 414                None            monthly
# ...                 ...                ...
# 671151             None            monthly
# 671174             None            monthly
# 671178             None            monthly
# 671185             None            monthly
# 671202             None            monthly
#
# [4233 rows x 12 columns]

# %% [markdown]
# **Erkenntnis:**
# - NaN in 'borrower_genders' und 'use' scheint zusammenzuhängen - das wird genauer geprüft:

# %%
# Welche Zeilen enthalten NULL-Werte in Spalte 'use' und in Spalte 'borrower_genders'?
df.loc[(df.loc[:,"borrower_genders"].isnull()) & (df.loc[:,"use"].isnull())]
# Out:
#         funded_amount  loan_amount               activity         sector  \
# 140            2975.0       2975.0  Food Production/Sales           Food
# 145            1200.0       1200.0      Personal Expenses   Personal Use
# 170            4250.0       4250.0               Catering           Food
# 412            2350.0       2350.0           Beauty Salon       Services
# 414             725.0        725.0            Agriculture    Agriculture
# ...               ...          ...                    ...            ...
# 671151            0.0         25.0              Livestock    Agriculture
# 671174            0.0         25.0                  Games  Entertainment
# 671178            0.0         25.0              Livestock    Agriculture
# 671185            0.0         25.0              Livestock    Agriculture
# 671202            0.0         25.0                  Games  Entertainment
#
#          use country_code      country currency  term_in_months  lender_count  \
# 140     None           TZ     Tanzania      TZS            10.0           110
# 145     None           PE         Peru      PEN            20.0            44
# 170     None           TZ     Tanzania      TZS            10.0           116
# 412     None           TZ     Tanzania      TZS            10.0            75
# 414     None           SV  El Salvador      USD            20.0            19
# ...      ...          ...          ...      ...             ...           ...
# 671151  None           KE        Kenya      KES            13.0             0
# 671174  None           KE        Kenya      KES            13.0             0
# 671178  None           KE        Kenya      KES            13.0             0
# 671185  None           KE        Kenya      KES            13.0             0
# 671202  None           KE        Kenya      KES            13.0             0
#
#        borrower_genders repayment_interval
# 140                None            monthly
# 145                None            monthly
# 170                None            monthly
# 412                None            monthly
# 414                None            monthly
# ...                 ...                ...
# 671151             None            monthly
# 671174             None            monthly
# 671178             None            monthly
# 671185             None            monthly
# 671202             None            monthly
#
# [4221 rows x 12 columns]

# %% [markdown]
# **Erkenntnis:**
# - jede Zeile, in der 'borrower_genders' NaN ist, ist auch 'use' NaN
#     - hier wurden Daten anscheinend unzureichend eingegeben
#     - beides kann nicht sinnvoll aufgefüllt werden (da string-Spalte und sehr viele unique values)
#     - die Spalte 'use' zu löschen kommt ggf. in Frage, da diese aufgrund der freien Eingabemöglichkeit nur sehr schwer zu analysieren ist und für meine späteren Analysen nicht in Frage kommt
#     - die Spalte 'borrower_genders' zu löschen kommt nicht Frage, da diese Spalte später für KPIs verwendet wird und daher gut analysiert werden kann
#
# **Ergebnis der Erkenntnis:**<br>
# **Ich werde die Zeilen, in denen beide Werte NaN, sind löschen.** So behalte ich die Analysemöglichkeit für 'borrower_genders' bei und bereinige die Daten (ich gehe damit ja nicht ins Machine Learning)

# %%
# Liste mit Indizes für zu löschende Spalten erstellen
index_to_drop = df.loc[(df.loc[:,"borrower_genders"].isnull()) & (df.loc[:,"use"].isnull())].index

# Zeilen anhand dieses Index löschen
df.drop(index=index_to_drop, inplace=True)

# %% [markdown]
# Es gibt aber weiterhin Zeilen in 'use', die NaN sind, die schauen wir uns nochmal an:

# %%
# NULL-Werte in Spalte 'use' genauer anschauen
df.loc[df.loc[:, 'use'].isnull(), :]
# Out:
#         funded_amount  loan_amount               activity        sector   use  \
# 77120           200.0       5000.0             Technology      Services  None
# 118362         2475.0       2475.0  Food Production/Sales          Food  None
# 121644         1350.0       1350.0           Fish Selling          Food  None
# 187286          235.0       4000.0             Technology      Services  None
# 195101          650.0        650.0            Agriculture   Agriculture  None
# 208234          100.0       5000.0               Clothing      Clothing  None
# 211047            0.0       5000.0  Food Production/Sales          Food  None
# 247724            0.0       3000.0               Services      Services  None
# 292739          750.0       1175.0         Clothing Sales      Clothing  None
# 362573          100.0        100.0                Farming   Agriculture  None
# 452286          200.0        200.0        Home Appliances  Personal Use  None
# 479359          700.0        700.0                   Pigs   Agriculture  None
#
#        country_code        country currency  term_in_months  lender_count  \
# 77120            US  United States      USD            24.0             2
# 118362           RW         Rwanda      RWF             4.0            21
# 121644           CO       Colombia      COP            14.0            54
# 187286           US  United States      USD            24.0             9
# 195101           SV    El Salvador      USD            15.0            21
# 208234           US  United States      USD            12.0             2
# 211047           US  United States      USD            24.0             0
# 247724           US  United States      USD            18.0             0
# 292739           KE          Kenya      KES            14.0            11
# 362573           MZ     Mozambique      MZN             7.0             4
# 452286           KH       Cambodia      KHR             8.0             7
# 479359           KH       Cambodia      KHR            11.0            16
#
#                                          borrower_genders repayment_interval
# 77120                                              female             bullet
# 118362  male, female, female, female, female, female, ...          irregular
# 121644                                             female            monthly
# 187286                                             female             bullet
# 195101                                             female             bullet
# 208234                                               male             bullet
# 211047                                             female             bullet
# 247724                                             female             bullet
# 292739                                               male            monthly
# 362573                                               male            monthly
# 452286                 female, male, female, female, male            monthly
# 479359                                     female, female            monthly

# %% [markdown]
# **Erkenntnis:**
# - 'use' kann nicht sinnvoll aufgefüllt werden (wie oben schon beschrieben)
# - die Zeilen zu löschen nimmt uns interessant Daten aus anderen Spalten weg
# - 'use' zu löschen nimmt zwar gesamte Daten aus dieser Spalte raus, allerdings sind diese, durch die Möglichkeit freien Text einzugeben, sehr schwer in diesem Detail zu analysieren
#
# **Ergebnis der Erkenntnis:**<br>
# **Die Spalte 'use' wird gelöscht.**

# %%
# Entfernen von Spalte 'use'
df.drop(columns='use', inplace=True)

# %% [markdown]
# #### Spalte 'country_code'

# %%
# NULL-Werte in Spalte 'country_code' genauer anschauen
df.loc[df.loc[:, 'country_code'].isnull(), :]
# Out:
#         funded_amount  loan_amount                   activity     sector  \
# 202537         4150.0       4150.0                  Wholesale  Wholesale
# 202823         4150.0       4150.0                  Wholesale  Wholesale
# 344929         3325.0       3325.0                  Wholesale  Wholesale
# 351177         3325.0       3325.0                  Wholesale  Wholesale
# 420953         3325.0       3325.0                  Wholesale  Wholesale
# 421218         4000.0       4000.0                  Wholesale  Wholesale
# 487207         5100.0       5100.0  Renewable Energy Products     Retail
# 487653         5000.0       5000.0                  Wholesale  Wholesale
#
#        country_code  country currency  term_in_months  lender_count  \
# 202537         None  Namibia      NAD             6.0           162
# 202823         None  Namibia      NAD             6.0           159
# 344929         None  Namibia      NAD             7.0           120
# 351177         None  Namibia      NAD             7.0           126
# 420953         None  Namibia      NAD             7.0           118
# 421218         None  Namibia      NAD             7.0           150
# 487207         None  Namibia      NAD             7.0           183
# 487653         None  Namibia      NAD             7.0           183
#
#        borrower_genders repayment_interval
# 202537           female             bullet
# 202823             male             bullet
# 344929           female             bullet
# 351177             male             bullet
# 420953           female             bullet
# 421218             male             bullet
# 487207             male             bullet
# 487653           female             bullet

# %% [markdown]
# **Erkenntnis:**
# - Auffällig: nur Namibia hat NULL-Werte im Ländercode
#     - Google: Ländercode nach ISO Norm (zweistellig) von Namibia: NA
#
# **Ergebnis der Erkenntnis:**<br>
# Scheint systemseitig ein Fehler unterlaufen zu sein, **NaN in Ländercode durch NA für Namibia ersetzen**

# %%
# NaN in 'country_code' durch NA ersetzen (Namibia)
df['country_code'].fillna('NA', inplace=True)

# %% [markdown]
# Jetzt prüfe ich nochmal, ob es im df noch NULL-Werte gibt:

# %%
# Spalten mit NULL-Werte nochmals prüfen
df.isnull().sum().sort_values(ascending=False)
# Out:
# funded_amount         0
# loan_amount           0
# activity              0
# sector                0
# country_code          0
# country               0
# currency              0
# term_in_months        0
# lender_count          0
# borrower_genders      0
# repayment_interval    0
# dtype: int64

# %%
# df als neues df_clean abspeichern
df_clean = df.copy()

# %% [markdown]
# ## Ausreißer vs. Extremwerte

# %% [markdown]
# Da wir keine statistische oder rein Marketing bezogene Auswertung machen, sprechen wir nicht von Ausreißern und entfernen diese, sondern wir sprechen von Extremwerten. Diese werden beibehalten, um den betriebswirtschaftlichen Blick fürs große Ganze zu behalten. Wenn Personen (-gruppen) ein extrem hohes funding verlangt und/oder bekommen haben, dann sollen diese beibehalten und analysiert werden. Das gleiche gilt für Ober- und Unterkategorien (Über- und Unterrepräsentation), Länder (geographische Verteilung) und alle anderen Werte.

# %% [markdown]
# ## Zusatz

# %% [markdown]
# ### KPIs

# %%
# nochmal das df aufrufen, um KPIs zu identifizieren
df_clean
# Out:
#         funded_amount  loan_amount             activity          sector  \
# 0               300.0        300.0  Fruits & Vegetables            Food
# 1               575.0        575.0             Rickshaw  Transportation
# 2               150.0        150.0       Transportation  Transportation
# 3               200.0        200.0           Embroidery            Arts
# 4               400.0        400.0           Milk Sales            Food
# ...               ...          ...                  ...             ...
# 671199            0.0         25.0            Livestock     Agriculture
# 671200            0.0         25.0            Livestock     Agriculture
# 671201           25.0         25.0            Livestock     Agriculture
# 671203            0.0         25.0            Livestock     Agriculture
# 671204            0.0         25.0            Livestock     Agriculture
#
#        country_code   country currency  term_in_months  lender_count  \
# 0                PK  Pakistan      PKR            12.0            12
# 1                PK  Pakistan      PKR            11.0            14
# 2                IN     India      INR            43.0             6
# 3                PK  Pakistan      PKR            11.0             8
# 4                PK  Pakistan      PKR            14.0            16
# ...             ...       ...      ...             ...           ...
# 671199           PY  Paraguay      USD            13.0             0
# 671200           PY  Paraguay      USD            13.0             0
# 671201           KE     Kenya      KES            13.0             1
# 671203           KE     Kenya      KES            13.0             0
# 671204           KE     Kenya      KES            13.0             0
#
#        borrower_genders repayment_interval
# 0                female          irregular
# 1        female, female          irregular
# 2                female             bullet
# 3                female          irregular
# 4                female            monthly
# ...                 ...                ...
# 671199           female            monthly
# 671200           female            monthly
# 671201           female            monthly
# 671203           female            monthly
# 671204           female            monthly
#
# [666984 rows x 11 columns]

# %% [markdown]
# #### Erfüllungsgrad

# %% [markdown]
# Für später könnte es interessant sein, den Erfüllungsgrad in Abhängigkeit verschiedener Kriterien zu analysieren. Dafür wird eine weitere Spalte 'completion_rate' erstellt.

# %%
# neue Spalte als dritte Spalte einfügen (Berechnung: fund_amount / loan_amount)
df_clean.insert(
    loc=2,
    column='completion_rate',
    value= df_clean['funded_amount'] / df_clean['loan_amount']
)

# df mit neuer Spalte ausgeben
df_clean
# Out:
#         funded_amount  loan_amount  completion_rate             activity  \
# 0               300.0        300.0              1.0  Fruits & Vegetables
# 1               575.0        575.0              1.0             Rickshaw
# 2               150.0        150.0              1.0       Transportation
# 3               200.0        200.0              1.0           Embroidery
# 4               400.0        400.0              1.0           Milk Sales
# ...               ...          ...              ...                  ...
# 671199            0.0         25.0              0.0            Livestock
# 671200            0.0         25.0              0.0            Livestock
# 671201           25.0         25.0              1.0            Livestock
# 671203            0.0         25.0              0.0            Livestock
# 671204            0.0         25.0              0.0            Livestock
#
#                 sector country_code   country currency  term_in_months  \
# 0                 Food           PK  Pakistan      PKR            12.0
# 1       Transportation           PK  Pakistan      PKR            11.0
# 2       Transportation           IN     India      INR            43.0
# 3                 Arts           PK  Pakistan      PKR            11.0
# 4                 Food           PK  Pakistan      PKR            14.0
# ...                ...          ...       ...      ...             ...
# 671199     Agriculture           PY  Paraguay      USD            13.0
# 671200     Agriculture           PY  Paraguay      USD            13.0
# 671201     Agriculture           KE     Kenya      KES            13.0
# 671203     Agriculture           KE     Kenya      KES            13.0
# 671204     Agriculture           KE     Kenya      KES            13.0
#
#         lender_count borrower_genders repayment_interval
# 0                 12           female          irregular
# 1                 14   female, female          irregular
# 2                  6           female             bullet
# 3                  8           female          irregular
# 4                 16           female            monthly
# ...              ...              ...                ...
# 671199             0           female            monthly
# 671200             0           female            monthly
# 671201             1           female            monthly
# 671203             0           female            monthly
# 671204             0           female            monthly
#
# [666984 rows x 12 columns]

# %% [markdown]
# #### 'borrower_genders' aufgeschlüsselt

# %% [markdown]
# Die Spalte 'borrower_genders' enthält mehrere Infos: die Anzahl der Darlehensnehmer und deren Geschlecht. Diese Info kann gut auf zwei Spalten aufgeteilt werden, um diese für Analysen nutzen zu können.

# %%
# neue Spalte mit Anzahl der Darlehensnehmer erstellen
df_clean.insert(
    loc=11,
    column='borrower_count',
    value=df_clean['borrower_genders'].str.count(',') + 1 # zähle Kommas und addiere 1 -> Darlehensnehmeranzahl
)

# df mit neuer Spalte ausgeben
# df_clean

# %%
# Spalte borrowers_genders direkt daneben duplizieren
df_clean.insert(
    loc=12,
    column='borrower_genders_edited',
    value=df_clean['borrower_genders']
)

# df mit neuer Spalte ausgeben
# df_clean

# %%
# in neuer Spalte female und male mit fe und ma ersetzen
df_clean['borrower_genders_edited'] = df_clean['borrower_genders_edited'].str.replace('female', 'fe')
df_clean['borrower_genders_edited'] = df_clean['borrower_genders_edited'].str.replace('male', 'ma')

# %%
# neue Spalte mit Angabe, ob Darlehensnehmer min 1 female enthält, erstellen
df_clean.insert(
    loc=13,
    column='female',
    value=df_clean['borrower_genders_edited'].str.contains('fe')
)

# neue Spalte mit Angabe, ob Darlehensnehmer min 1 male enthält, erstellen
df_clean.insert(
    loc=14,
    column='male',
    value=df_clean['borrower_genders_edited'].str.contains('ma')
)

# df mit neuer Spalte ausgeben
# df_clean

# %%
# neue Spalte erstellen, die Geschlecht: male, female und mixed enthalten soll
df_clean.insert(
    loc=15,
    column='borrower_genders_updated',
    value=None
)

# Wertzuweisung male only
df_clean.loc[
    (df_clean.loc[:, 'female'] == False) &
    (df_clean.loc[:, 'male'] == True)
    , 'borrower_genders_updated'] = 'ma only'

# Wertzuweisung female only
df_clean.loc[
    (df_clean.loc[:, 'female'] == True) &
    (df_clean.loc[:, 'male'] == False)
    , 'borrower_genders_updated'] = 'fe only'

# Wertzuweisung mixed
df_clean.loc[
    (df_clean.loc[:, 'female'] == True) &
    (df_clean.loc[:, 'male'] == True)
    , 'borrower_genders_updated'] = 'mixed'

# %% [markdown]
# Hier die Spalte 'borrower_genders' und die daraus erstellten neuen Spalten:

# %%
# Anzeigen der neu erstellten Spalten und 'borrower_genders'
df_clean.iloc[:, 10:16]
# Out:
#        borrower_genders  borrower_count borrower_genders_edited  female  \
# 0                female               1                      fe    True
# 1        female, female               2                  fe, fe    True
# 2                female               1                      fe    True
# 3                female               1                      fe    True
# 4                female               1                      fe    True
# ...                 ...             ...                     ...     ...
# 671199           female               1                      fe    True
# 671200           female               1                      fe    True
# 671201           female               1                      fe    True
# 671203           female               1                      fe    True
# 671204           female               1                      fe    True
#
#          male borrower_genders_updated
# 0       False                  fe only
# 1       False                  fe only
# 2       False                  fe only
# 3       False                  fe only
# 4       False                  fe only
# ...       ...                      ...
# 671199  False                  fe only
# 671200  False                  fe only
# 671201  False                  fe only
# 671203  False                  fe only
# 671204  False                  fe only
#
# [666984 rows x 6 columns]

# %% [markdown]
# #### Investierter Beitrag pro Investor

# %% [markdown]
# Für spätere Auswertungen könnte der investierte Betrag pro Investor ebenfalls interessant sein. Dazu erstelle ich einen neue Spalte, die funded_amount / lender_count enthält.

# %%
# neue Spalte erstellen und mit investiertem Betrag pro Investor befüllen
df_clean.insert(
    loc=11,
    column='funded_amount_per_lender',
    value=round(df_clean['funded_amount'] / df_clean['lender_count'], 2)
)

# NULL-Werte durch 0 ersetzen
df_clean['funded_amount_per_lender'].fillna(0, inplace=True)

# %% [markdown]
# ### Speicherplatzoptimierung

# %% [markdown]
# #### Spalten entfernen

# %% [markdown]
# Für spätere Analysen werden folgende Spalten nicht benötigt:
# - 'country_code' (Info steht ja auch in Spalte 'country')
# - 'currency' (Währung, in der ausgezahlt wird, ist für meine Analysen nicht relevant)
# - 'borrower_genders' (habe ich mit anderen Spalten besser abgebildet)
# - 'borrower_genders_edited', 'female' & 'male' (nur Hilfsspalten)

# %%
# neues df erstellen für Optimierung
df_clean_opti = df_clean.copy()

# %%
# oben aufgeführte Spalten entfernen
df_clean_opti.drop(columns=['country_code', 'currency', 'borrower_genders', 'borrower_genders_edited', 'female', 'male'], inplace=True)

# %% [markdown]
# #### Konvertieren und Downcasten

# %%
# wie sehen nochmal die dtypes der Spalten aus?
df_clean_opti.dtypes
# Out:
# funded_amount               float64
# loan_amount                 float64
# completion_rate             float64
# activity                     object
# sector                       object
# country                      object
# term_in_months              float64
# lender_count                  int64
# funded_amount_per_lender    float64
# borrower_count                int64
# borrower_genders_updated     object
# repayment_interval           object
# dtype: object

# %%
# testen, ob 'funded_amount' in int konvertiert werden kann
for number in df_clean_opti['funded_amount']:
    if number %1 != 0:                        # ist der Restwert nicht Null, dann liegt ein float vor
        print('do not convert to integer') 
print('do convert to integer')
# Out:
# do convert to integer

# %%
# testen, ob 'loan_amount' in int konvertiert werden kann
for number in df_clean_opti['loan_amount']:
    if number %1 != 0:                        # ist der Restwert nicht Null, dann liegt ein float vor
        print('do not convert to integer') 
print('do convert to integer')
# Out:
# do convert to integer

# %%
# testen, ob 'term_in_months' in int konvertiert werden kann
for number in df_clean_opti['term_in_months']:
    if number %1 != 0:                        # ist der Restwert nicht Null, dann liegt ein float vor
        print('do not convert to integer') 
print('do convert to integer')
# Out:
# do convert to integer

# %% [markdown]
# **Erkenntnis:**
# - die drei untersuchten Spalten können konvertiert werden
# - die zuvor neu erstellten Spalten müssen nicht konvertiert werden (sind ja per Definition dezimal)

# %%
# die drei geprüften Spalten konvertieren und direkt downcasten
df_clean_opti['funded_amount'] = pd.to_numeric(df_clean_opti['funded_amount'], downcast='integer')
df_clean_opti['loan_amount'] = pd.to_numeric(df_clean_opti['loan_amount'], downcast='integer')
df_clean_opti['term_in_months'] = pd.to_numeric(df_clean_opti['term_in_months'], downcast='integer')

# int64 Spalten downcasten
df_clean_opti['lender_count'] = pd.to_numeric(df_clean_opti['lender_count'], downcast='integer')
df_clean_opti['borrower_count'] = pd.to_numeric(df_clean_opti['borrower_count'], downcast='integer')

# float64 Spalten downcasten
df_clean_opti['completion_rate'] = pd.to_numeric(df_clean_opti['completion_rate'], downcast='float')
df_clean_opti['funded_amount_per_lender'] = pd.to_numeric(df_clean_opti['funded_amount_per_lender'], downcast='float')

# dtypes prüfen
df_clean_opti.dtypes
# Out:
# funded_amount                 int32
# loan_amount                   int32
# completion_rate             float32
# activity                     object
# sector                       object
# country                      object
# term_in_months                int16
# lender_count                  int16
# funded_amount_per_lender    float32
# borrower_count                 int8
# borrower_genders_updated     object
# repayment_interval           object
# dtype: object

# %% [markdown]
# #### Category dtype

# %%
# Liste erstellen, die Spaltennamen von Spalten mit dtype object enthält
liste = df_clean_opti.select_dtypes("object").columns 

# durch diese Liste iterieren und die Anzahl unique values zu jeder Spalte ausgeben
for spalte in liste:
    print(spalte, df_clean_opti.loc[:,spalte].nunique())
# Out:
# activity 163
# sector 15
# country 87
# borrower_genders_updated 3
# repayment_interval 4

# %% [markdown]
# **Erkenntnis:**
# - alle Spalten enthalten deutlich weniger unique values als Zeilen in dem df sind
#     - also konvertiere ich alle in einen category dtype

# %%
# Umwandlung in Category Datentyp - mit astype()

# Liste mit zu konvertierenden Spalten erstellen
liste_category = ['activity','sector','country','borrower_genders_updated', 'repayment_interval']

# durch die Liste iterieren und umwandeln
for spalte in liste_category:
    df_clean_opti[spalte] = df_clean[spalte].astype('category')

# dtypes prüfen
df_clean_opti.dtypes
# Out:
# funded_amount                  int32
# loan_amount                    int32
# completion_rate              float32
# activity                    category
# sector                      category
# country                     category
# term_in_months                 int16
# lender_count                   int16
# funded_amount_per_lender     float32
# borrower_count                  int8
# borrower_genders_updated    category
# repayment_interval          category
# dtype: object

# %%
# Vergleich der Speicherplatznutzung
print(df_clean_opti.memory_usage(deep=True))
print()
print(df_clean.memory_usage(deep=True))
# Out:
# Index                       5335872
# funded_amount               2667936
# loan_amount                 2667936
# completion_rate             2667936
# activity                    1349429
# sector                       668531
# country                      674808
# term_in_months              1333968
# lender_count                1333968
# funded_amount_per_lender    2667936
# borrower_count               666984
# borrower_genders_updated     667282
# repayment_interval           667412
# dtype: int64
#
# Index                        5335872
# funded_amount                5335872
# loan_amount                  5335872
# completion_rate              5335872
# activity                    46228811
# sector                      43330076
# country_code                39352056
# country                     43649696
# currency                    40019040
# term_in_months               5335872
# lender_count                 5335872
# borrower_genders            46904008
# funded_amount_per_lender     5335872
# borrower_count               5335872
# borrower_genders_edited     42068968
# female                        666984
# male                          666984
# borrower_genders_updated    42606216
# repayment_interval          43129882
# dtype: int64

# %% [markdown]
# ## Speichern

# %%
# optimiertes df als pickle Datei speichern (um Speicherplatzoptimierung beizubehalten)
df_clean_opti.to_pickle('df_kiva_after_preprocessing.pkl')
